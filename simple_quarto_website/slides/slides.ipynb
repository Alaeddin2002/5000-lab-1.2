# %% [markdown]
# ---
# title: "About Me"
# author: "Ihsan Alaeddin"
# format: revealjs
# bibliography: ../reference.bib
#
# ---
#
# ## Background
#
# - I was born in San Francisco, California
# - Moved to Palestine when I was 6 months old
# - Raised in Ramallah, Palestine
# - Came to America for Undergrad
# - Moved to America for Grad
#
# ## My Hobbies
#
# - Soccer
# - Socializing
# - Hiking
#
# ![Watching Soccer](images/soccer.jpg){fig-align="right" width=300 height=200}
# ![Hiking](images/Hiking.JPG){fig-align="right" width=300 height=200}
#
# ## Career Interests
#
# - AI Engineer
# - Finance
# - Data Scientist
# - Learnt a lot about AI from the article "Annotated History of Modern AI and Deep Learning" [@schmidhuber2022annotatedhistorymodernai].
#
#
# ## Visualisation of my Current Interests

# %%
#| echo: true
#| code-fold: true
import matplotlib.pyplot as plt
import numpy as np

y = np.array([50, 10, 20, 20])
mylabels = ["Soccer", "Hiking", "Data Science", "AI"]

plt.pie(y, labels = mylabels)
plt.title("My Current Interests")
plt.show()

# %% [markdown]
# ## References
